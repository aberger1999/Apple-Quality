# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
import pandas as pd

# Load the file into a DataFrame
apple_quality = pd.read_csv("apple_quality.csv")

apple_quality.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good

# %%
# Get the dimensions of the dataset
dimensions = apple_quality.shape
print("Number of rows:", dimensions[0])
print("Number of columns:", dimensions[1])
# Out:
# Number of rows: 4001
# Number of columns: 9

# %%
apple_quality.describe().T
# Out:
#               count         mean          std       min         25%  \
# A_id         4000.0  1999.500000  1154.844867  0.000000  999.750000
# Size         4000.0    -0.503015     1.928059 -7.151703   -1.816765
# Weight       4000.0    -0.989547     1.602507 -7.149848   -2.011770
# Sweetness    4000.0    -0.470479     1.943441 -6.894485   -1.738425
# Crunchiness  4000.0     0.985478     1.402757 -6.055058    0.062764
# Juiciness    4000.0     0.512118     1.930286 -5.961897   -0.801286
# Ripeness     4000.0     0.498277     1.874427 -5.864599   -0.771677
#
#                      50%          75%          max
# A_id         1999.500000  2999.250000  3999.000000
# Size           -0.513703     0.805526     6.406367
# Weight         -0.984736     0.030976     5.790714
# Sweetness      -0.504758     0.801922     6.374916
# Crunchiness     0.998249     1.894234     7.619852
# Juiciness       0.534219     1.835976     7.364403
# Ripeness        0.503445     1.766212     7.237837

# %%
apple_quality.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4001 entries, 0 to 4000
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   A_id         4000 non-null   float64
#  1   Size         4000 non-null   float64
#  2   Weight       4000 non-null   float64
#  3   Sweetness    4000 non-null   float64
#  4   Crunchiness  4000 non-null   float64
#  5   Juiciness    4000 non-null   float64
#  6   Ripeness     4000 non-null   float64
#  7   Acidity      4001 non-null   object
#  8   Quality      4000 non-null   object
# dtypes: float64(7), object(2)
# memory usage: 281.4+ KB

# %%
print(apple_quality.isnull().sum())
# Out:
# A_id           1
# Size           1
# Weight         1
# Sweetness      1
# Crunchiness    1
# Juiciness      1
# Ripeness       1
# Acidity        0
# Quality        1
# dtype: int64

# %%
apple_quality_cleaned = apple_quality.dropna()

print(apple_quality_cleaned.isnull().sum())
# Out:
# A_id           0
# Size           0
# Weight         0
# Sweetness      0
# Crunchiness    0
# Juiciness      0
# Ripeness       0
# Acidity        0
# Quality        0
# dtype: int64

# %%
apple_quality_cleaned
# Out:
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity Quality
# 0     -0.491590483    good
# 1     -0.722809367    good
# 2      2.621636473     bad
# 3      0.790723217    good
# 4      0.501984036    good
# ...            ...     ...
# 3995   0.137784369     bad
# 3996   1.854235285    good
# 3997  -1.334611391     bad
# 3998  -2.229719806    good
# 3999   1.599796456    good
#
# [4000 rows x 9 columns]

# %%
apple_quality_cleaned.columns
# Out:
# Index(['A_id', 'Size', 'Weight', 'Sweetness', 'Crunchiness', 'Juiciness',
#        'Ripeness', 'Acidity', 'Quality'],
#       dtype='object')

# %%
# Label encoding: 1 = good, 0 = bad
binary_labels = [1 if quality == "good" else 0 for quality in apple_quality_cleaned['Quality']]
apple_quality_cleaned['Quality'] = binary_labels
apple_quality_cleaned
# Out:
# /var/folders/zk/0r49mq7d0clfgycz8c472dn00000gn/T/ipykernel_9120/4290248628.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_quality_cleaned['Quality'] = binary_labels
#         A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0        0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1        1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2        2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3        3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4        4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
# ...      ...       ...       ...        ...          ...        ...       ...
# 3995  3995.0  0.059386 -1.067408  -3.714549     0.473052   1.697986  2.244055
# 3996  3996.0 -0.293118  1.949253  -0.204020    -0.640196   0.024523 -1.087900
# 3997  3997.0 -2.634515 -2.138247  -2.440461     0.657223   2.199709  4.763859
# 3998  3998.0 -4.008004 -1.779337   2.366397    -0.200329   2.161435  0.214488
# 3999  3999.0  0.278540 -1.715505   0.121217    -1.154075   1.266677 -0.776571
#
#            Acidity  Quality
# 0     -0.491590483        1
# 1     -0.722809367        1
# 2      2.621636473        0
# 3      0.790723217        1
# 4      0.501984036        1
# ...            ...      ...
# 3995   0.137784369        0
# 3996   1.854235285        1
# 3997  -1.334611391        0
# 3998  -2.229719806        1
# 3999   1.599796456        1
#
# [4000 rows x 9 columns]

# %%
#The feature A_id adds no value to the model and can be dropped
apple_quality_cleaned.drop("A_id", axis=1, inplace=True)
# Out:
# /var/folders/zk/0r49mq7d0clfgycz8c472dn00000gn/T/ipykernel_9120/3719967470.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apple_quality_cleaned.drop("A_id", axis=1, inplace=True)

# %%
numerical_columns = apple_quality_cleaned.select_dtypes(include=['float64', 'int64'])

for column in numerical_columns.columns:
    sns.histplot(apple_quality_cleaned[column], kde=True)
    plt.title(f'Distribution of {column}')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.show()

# %%
for i in apple_quality_cleaned.columns:
    plt.figure(figsize=(10, 2))
    sns.boxplot(data=apple_quality_cleaned, x=i)
    plt.show()

# %%
sns.countplot(data=apple_quality_cleaned, x='Quality')
plt.title('Countplot for Quality')
plt.xlabel('Quality')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#Correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(apple_quality_cleaned.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ## Model Preparation

# %%
#split data
X = apple_quality_cleaned.drop("Quality", axis=1)
y = apple_quality_cleaned.Quality
display(X.head())
display(y.head())
# Out:
#        Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity
# 0  -0.491590483
# 1  -0.722809367
# 2   2.621636473
# 3   0.790723217
# 4   0.501984036
# 0    1
# 1    1
# 2    0
# 3    1
# 4    1
# Name: Quality, dtype: int64

# %%
#Scale the features
sc = StandardScaler()
sc.fit_transform(X)
# Out:
# array([[-1.79842417, -0.95037339,  2.99342063, ...,  0.69054495,
#         -0.08987211, -0.26941526],
#        [-0.35906018, -1.15440431,  2.12769769, ...,  0.17676683,
#          0.1970196 , -0.37899737],
#        [ 0.1094454 , -0.22575916, -0.65250727, ...,  1.20542179,
#         -0.28615565,  1.20604367],
#        ...,
#        [-1.1056547 , -0.71690397, -1.01378401, ...,  0.87437918,
#          2.27595716, -0.66895013],
#        [-1.81811235, -0.49290842,  1.45990059, ...,  0.85454883,
#         -0.15141937, -1.09317096],
#        [ 0.40540882, -0.45307081,  0.30449592, ...,  0.39095445,
#         -0.68021237,  0.72176064]])

# %%
#Split data in trainset and testset
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2, random_state=42)

# %%
#Calculate precision, recall and F1
def perf_metrics(y_pred):
    # Calculate precision
    precision = precision_score(y_test, y_pred)

    # Calculate recall
    recall = recall_score(y_test, y_pred)

    # Calculate F1-score
    f1 = f1_score(y_test, y_pred)

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(y_test, y_pred)

    print("Precision:", precision)
    print("Recall:", recall)
    print("F1-score:", f1)
    print("Confusion Matrix:")
    print(conf_matrix)

# %% [markdown]
# ### Random Forest

# %%
RF_model = RandomForestClassifier(n_estimators=250, random_state=42)
RF_model.fit(X_train, y_train)

RF_predictions = RF_model.predict(X_test)

# %%
perf_metrics(RF_predictions)
# Out:
# Precision: 0.8456221198156681
# Recall: 0.9152119700748129
# F1-score: 0.8790419161676647
# Confusion Matrix:
# [[332  67]
#  [ 34 367]]

# %%
#optimize RF with hyperparameter tuning

# Define the parameter grid
param_grid = {
    'n_estimators': [100, 200, 300],  # Number of trees in the forest
    'max_depth': [None, 10, 20],       # Maximum depth of the trees
    'criterion': ['gini', 'entropy']
}
# Create GridSearchCV instance
grid_search = GridSearchCV(estimator=RF_model, param_grid=param_grid, cv=5, scoring='f1', verbose=True)

# Fit the grid search to the training data
grid_search.fit(X_train, y_train)

# Get the best parameters and best score
best_params = grid_search.best_params_
best_score = grid_search.best_score_

print("Best Parameters:", best_params)
print("Best Score:", best_score)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# Best Parameters: {'criterion': 'entropy', 'max_depth': None, 'n_estimators': 300}
# Best Score: 0.8876478571338533

# %%
#Retrain RF model with best parameters
RF_model = RandomForestClassifier(**best_params)
RF_model.fit(X_train, y_train)

RF_predictions = RF_model.predict(X_test)

perf_metrics(RF_predictions)
# Out:
# Precision: 0.8581560283687943
# Recall: 0.9052369077306733
# F1-score: 0.8810679611650486
# Confusion Matrix:
# [[339  60]
#  [ 38 363]]
